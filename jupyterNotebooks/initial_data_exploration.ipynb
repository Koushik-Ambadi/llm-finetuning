# %%
import json
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv('C://Users//koushik//Desktop//project//data//flat_dataset//initial_data1.csv')
df1.columns = [col.split('.')[-1] for col in df1.columns]
df1 = df1[df1['SummaryCategories'] != 'Folder']

# %%
'''

['fileversion','ShortName','Description','SummaryCategories','testCaseShoortName','process','State',
'RequirementID','expectedResults','testcaseId','refId','refMode','createdBy','modifiedBy','priority',
'externalId','externalScriptName','createdDate','modifiedDate','automatedBehavioronError','tocomment',
'fromcomment','displayOnTree','displayOnTable','precondition','postcondition','testSteps','path',
'documentId','status','version','updateversion','createdate','modifiedate','parentId','insertLocation',
'testcasePTCModifiedDate','summaryCategoriesModifyflag','descriptionModifyflag','testStepsModifyflag',
'preconditionModifyflag','postconditionModifyflag','expectedResultsModifyflag','parameterPtclistModifyflag',
'StateModifyflag','priorityModifyflag','tocommentModifyflag','statusflag','traceabiltyMofifyflag',
'mitescriptflag','checkBoxflag','testcaseenable','testScriptEditFlag','TestCaseFormid','ParametersList',
'deleterelations','file_name','Parameter','RelationShips','miteXmlData','testScriptName','ParameterValues']

'''
#  434 rows × 62 testScriptNamecolumns
# Out:
# "\n\n['fileversion','ShortName','Description','SummaryCategories','testCaseShoortName','process','State',\n'RequirementID','expectedResults','testcaseId','refId','refMode','createdBy','modifiedBy','priority',\n'externalId','externalScriptName','createdDate','modifiedDate','automatedBehavioronError','tocomment',\n'fromcomment','displayOnTree','displayOnTable','precondition','postcondition','testSteps','path',\n'documentId','status','version','updateversion','createdate','modifiedate','parentId','insertLocation',\n'testcasePTCModifiedDate','summaryCategoriesModifyflag','descriptionModifyflag','testStepsModifyflag',\n'preconditionModifyflag','postconditionModifyflag','expectedResultsModifyflag','parameterPtclistModifyflag',\n'StateModifyflag','priorityModifyflag','tocommentModifyflag','statusflag','traceabiltyMofifyflag',\n'mitescriptflag','checkBoxflag','testcaseenable','testScriptEditFlag','TestCaseFormid','ParametersList',\n'deleterelations','file_name','Parameter','RelationShips','miteXmlData','testScriptName','ParameterValues']\n\n"

# %%
string = 'SummaryCategories'
print(df1[string].isna().sum())
len(df1[string].unique())
# Out:
# 0
# 3

# %%
df1[df1[string].isna()]
# Out:
# Empty DataFrame
# Columns: [fileversion, ShortName, Description, SummaryCategories, testCaseShoortName, process, State, RequirementID, expectedResults, testcaseId, refId, refMode, createdBy, modifiedBy, priority, externalId, externalScriptName, createdDate, modifiedDate, automatedBehavioronError, tocomment, fromcomment, displayOnTree, displayOnTable, precondition, postcondition, testSteps, path, documentId, status, version, updateversion, createdate, modifiedate, parentId, insertLocation, testcasePTCModifiedDate, summaryCategoriesModifyflag, descriptionModifyflag, testStepsModifyflag, preconditionModifyflag, postconditionModifyflag, expectedResultsModifyflag, parameterPtclistModifyflag, StateModifyflag, priorityModifyflag, tocommentModifyflag, statusflag, traceabiltyMofifyflag, mitescriptflag, checkBoxflag, testcaseenable, testScriptEditFlag, TestCaseFormid, ParametersList, deleterelations, file_name, Parameter, RelationShips, miteXmlData, testScriptName, ParameterValues]
# Index: []
#
# [0 rows x 62 columns]

# %%
df1[string].value_counts()
# Out:
# SummaryCategories
# Test - HIL       418
# Test - System      8
# Test               8
# Name: count, dtype: int64

# %%
df1[df1[string]=='Test']
# Out:
#      fileversion               ShortName  \
# 257          1.1  TestCase-1732191035672
# 258          1.1  TestCase-1732191035708
# 259          1.1  TestCase-1732191035745
# 260          1.1  TestCase-1732191035786
# 261          1.1  TestCase-1732191035834
# 262          1.1  TestCase-1732191035880
# 263          1.1  TestCase-1732191035923
# 264          1.1  TestCase-1732191035961
#
#                                Description SummaryCategories  \
# 257       ONLY Pack Charge Inhibitiion Set              Test
# 258  ONLY Pack Charge Entry Inhibition Set              Test
# 259         ONLY Pack Drive Inhibition Set              Test
# 260   ONLY Pack Drive Entry Inhibition Set              Test
# 261         ONLY Pack Regen Inhibition Set              Test
# 262     ONLY Pack Ramp Down Inhibition Set              Test
# 263    ONLY Pack Full Power Inhibition Set              Test
# 264     ONLY Pack Pyro Fuse Inhibition Set              Test
#
#          testCaseShoortName  process   State  RequirementID  \
# 257  TestCase-1732191035672      NaN  Active            NaN
# 258  TestCase-1732191035708      NaN  Active            NaN
# 259  TestCase-1732191035745      NaN  Active            NaN
# 260  TestCase-1732191035786      NaN  Active            NaN
# 261  TestCase-1732191035834      NaN  Active            NaN
# 262  TestCase-1732191035880      NaN  Active            NaN
# 263  TestCase-1732191035923      NaN  Active            NaN
# 264  TestCase-1732191035961      NaN  Active            NaN
#
#                                        expectedResults      testcaseId  ...  \
# 257  Test Sequence :<br>At Step 1 : CAN Signal BATT...  JB01_HILVR_506  ...
# 258  Test Sequence :<br>At Step 1 : CAN Signal BATT...  JB01_HILVR_507  ...
# 259  Test Sequence :<br>At Step 1 : CAN Signal BATT...  JB01_HILVR_508  ...
# 260  Test Sequence :<br>At Step 1 : CAN Signal BATT...  JB01_HILVR_509  ...
# 261  Test Sequence :<br>At Step 1 : CAN Signal BATT...  JB01_HILVR_510  ...
# 262  Test Sequence :<br>At Step 1 : CAN Signal BATT...  JB01_HILVR_511  ...
# 263  Test Sequence :<br>At Step 1 : CAN Signal BATT...  JB01_HILVR_512  ...
# 264  Test Sequence :<br>At Step 1 : CAN Signal BATT...  JB01_HILVR_513  ...
#
#      testScriptEditFlag                                     TestCaseFormid  \
# 257                True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 258                True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 259                True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 260                True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 261                True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 262                True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 263                True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 264                True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
#
#                                         ParametersList deleterelations  \
# 257  [{'no': '1', 'name': 'BATT_Pack_Inhibition.BAT...             NaN
# 258  [{'no': '1', 'name': 'BATT_Pack_Inhibition.BAT...             NaN
# 259  [{'no': '1', 'name': 'BATT_Pack_Inhibition.BAT...             NaN
# 260  [{'no': '1', 'name': 'BATT_Pack_Inhibition.BAT...             NaN
# 261  [{'no': '1', 'name': 'BATT_Pack_Inhibition.BAT...             NaN
# 262  [{'no': '1', 'name': 'BATT_Pack_Inhibition.BAT...             NaN
# 263  [{'no': '1', 'name': 'BATT_Pack_Inhibition.BAT...             NaN
# 264  [{'no': '1', 'name': 'BATT_Pack_Inhibition.BAT...             NaN
#
#                   file_name Parameter RelationShips miteXmlData  \
# 257  TestCase-1732191035672       NaN           NaN         NaN
# 258  TestCase-1732191035708       NaN           NaN         NaN
# 259  TestCase-1732191035745       NaN           NaN         NaN
# 260  TestCase-1732191035786       NaN           NaN         NaN
# 261  TestCase-1732191035834       NaN           NaN         NaN
# 262  TestCase-1732191035880       NaN           NaN         NaN
# 263  TestCase-1732191035923       NaN           NaN         NaN
# 264  TestCase-1732191035961       NaN           NaN         NaN
#
#     testScriptName ParameterValues
# 257            NaN             NaN
# 258            NaN             NaN
# 259            NaN             NaN
# 260            NaN             NaN
# 261            NaN             NaN
# 262            NaN             NaN
# 263            NaN             NaN
# 264            NaN             NaN
#
# [8 rows x 62 columns]

# %%
df_testcase=pd.read_excel('C://Users//koushik//Desktop//project//data//new_data//dataset_mite//Degradation//testcase.xls')
df_testcase.head(5)
# Out:
#     Section     Category Reference Mode  \
# 0       2.9  System Test         Author
# 1      3.11      Heading         Author
# 2    3.11.1      Comment         Author
# 3  3.11.1.1      Comment         Author
# 4  3.11.1.2      Comment         Author
#
#                                          Text       ID  Document ID Validates  \
# 0                            PreCondition TSR  9649554      8078526       NaN
# 1                                         TSR  9651341      8078526       NaN
# 2  Degradation Critical Reason Internal_Error  9651343      8078526       NaN
# 3               Driving direction not forward  9651345      8078526       NaN
# 4                   Activation of Robust Mode  9651347      8078526       NaN
#
#                          External ID Priority External Script Name  \
# 0  TestEnvMonHil_Mite_FullyAutomated      Low      Fully Automated
# 1                                NaN      NaN      Fully Automated
# 2  TestEnvMonHil_Mite_FullyAutomated      NaN      Fully Automated
# 3  TestEnvMonHil_Mite_FullyAutomated      NaN      Fully Automated
# 4  TestEnvMonHil_Mite_FullyAutomated      NaN      Fully Automated
#
#          Created Date Status_fld  \
# 0 2020-05-29 02:09:52   reviewed
# 1 2020-05-29 13:57:33      draft
# 2 2020-05-29 13:57:34      draft
# 3 2020-05-29 13:57:35      draft
# 4 2020-05-29 13:57:36      draft
#
#                                         Precondition  \
# 0                                                NaN
# 1                                                NaN
# 2  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 3  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 4  Step 1 : Run Test Case 9649554 TestSequence\nS...
#
#                                  Magna-Test Sequence  \
# 0  Step 1 : Set ECU Input PowerSupplyOff to 0\nSt...
# 1                                                NaN
# 2  Step 1 : Set ECU Calibration TSR_V_FiMXcpLowDe...
# 3  Step 1 : Set ECU Calibration TSR_V_FiMXcpLowDe...
# 4  Step 1 : Set ECU Calibration TSR_V_FiMXcpLowDe...
#
#                                   Postcondition  \
# 0                                           NaN
# 1                                           NaN
# 2  Step 1 : Run Test Case 10726201 TestSequence
# 3  Step 1 : Run Test Case 10726201 TestSequence
# 4  Step 1 : Run Test Case 10726201 TestSequence
#
#                                     Expected Results
# 0  Test Sequence :\nAt Step 11 : ECU Input Curren...
# 1                                                NaN
# 2  Pre Conditions :\nAt Step 6 : Diagnostic Respo...
# 3  Pre Conditions :\nAt Step 6 : Diagnostic Respo...
# 4  Pre Conditions :\nAt Step 6 : Diagnostic Respo...

# %%
string = 'Validates'
print(df_testcase[string].isna().sum())
len(df_testcase[string].unique())
# Out:
# 2
# 16

# %%
df_testcase[string].value_counts()
# Out:
# Validates
# 11266802, 10036670                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                6
# 11266802                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          4
# 10036668                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          4
# 10036670, 11267020, 11267022                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      3
# 10036670, 11266806, 11267062                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      3
# 10036670, 11266948                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                3
# 10036670, 11266802                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                3
# 11266930, 11266928, 11266798, 10036670                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            3
# 12154424, 11267012, 11267010, 10036670                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            3
# 10036670, 11266810, 11266812, 11266814, 11266816, 11266818, 11266820, 11266822, 11266824, 11266826, 11266828, 11266830, 11266832, 11266838, 11266840, 11266842, 11266844, 11266846, 11266848, 11266850, 11266852, 11266858, 11266860, 11266862, 11266864, 11266866, 11266868, 11266870, 11266872, 11266874, 11266876, 11266878, 11266880, 11266882, 11266886, 11266888, 11266890, 11266892, 11266894, 11266910, 11266912, 11266914, 11266916, 11266918, 11266920, 11266922, 11266924, 11266932, 11266934, 11266954, 11266952, 11266956, 11266958, 11266960, 11266962, 11266964, 11266966, 11266968, 11266970, 11266972, 11266974, 11266976, 11266978, 11266980, 11266982, 11266984, 11266986, 11266988, 11266990, 11266992, 11266994, 11303579    2
# 12154407, 11267000, 11267008, 10036670                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            2
# 12154144, 11267004, 11267002, 12154520, 11267016, 11267018, 12154541, 12154460, 12154558, 12154466, 12154564, 12154562, 12154479, 11267032, 10036670                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              2
# 12154407, 11267000, 11267008?, 10036670                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# 10036670, 12154144, 11267002, 11267004, 12154520, 11267016, 11267018, 12154541, 12154460, 12154558, 12154466, 12154564, 12154562, 12154479, 11267032                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# 11266810, 11266812, 11266814, 11266816, 11266818, 11266820, 11266822, 11266824, 11266826, 11266828, 11266830, 11266832, 11266838, 11266840, 11266842, 11266844, 11266846, 11266848, 11266850, 11266852, 11266858, 11266860, 11266862, 11266864, 11266866, 11266868, 11266870, 11266872, 11266874, 11266876, 11266878, 11266880, 11266882, 11266886, 11266888, 11266890, 11266892, 11266894, 11266910, 11266912, 11266914, 11266916, 11266918, 11266920, 11266922, 11266924, 11266932, 11266934, 11266952, 11266954, 11266956, 11266958, 11266960, 11266962, 11266964, 11266966, 11266968, 11266970, 11266972, 11266974, 11266976, 11266978, 11266980, 11266982, 11266984, 11266986, 11266988, 11266990, 11266992, 11266994, 11303579, 10036670    1
# Name: count, dtype: int64

# %%
df1[df1[string].isna()]
# Out:
#        Category               Text        ID Validates  \
# 0   System Test   PreCondition TSR   9649554       NaN
# 43  System Test  PostCondition TSR  10726201       NaN
#
#                               External ID Priority Precondition  \
# 0       TestEnvMonHil_Mite_FullyAutomated      Low          NaN
# 43  TestEnvMonitor_Mite_Dlt_SemiAutomated      Low          NaN
#
#                                   Magna-Test Sequence Postcondition
# 0   Step 1 : Set ECU Input PowerSupplyOff to 0\nSt...           NaN
# 43  Step 1 : Wait Time 1 for 1secs\nStep 2 : Send ...           NaN

# %%
df_testcase.drop(['Reference Mode','Section','Document ID','External Script Name','Created Date','Status_fld','Expected Results'],axis=1,inplace=True)

# %%
2.5.7.2	10036670	5703669	Functional Requirement	"The TSR Feature shall be designed to have priority for degradations.
High priority degradation shall over write the Low Priority degradation."	3628201	9651351, 9651355, 9651357, 9651359, 11444430, 11444432, 9651361, 9651363, 9651365, 12208730, 12208733, 12208741, 12208743, 12208749, 12208765, 12208791, 12208793, 12208795, 12208797, 12208799, 12208801, 12208803, 12208807, 12208809, 12208812, 12208817, 12208819, 11922652, 12208821, 12208823, 11922654, 12208829, 12208838	20625821, 20625954		System Bench
2.5.7.4.1	11266802	5703669	Functional Requirement	Adcam_Low system shall degrade Traffic Sign Recognition feature for required Calibration faults and set a primary DTC.	4649558, 3628794, 4651829, 4653483	9651351, 9651365, 12208730, 12208733, 12208817, 12208819, 11444422, 11444424, 11444426, 11444428, 9651357, 12208749, 12208765	20625821, 20625954		Traced to lower level

# %%
df_testcase=df_testcase[df_testcase['Category']=='System Test']

# %%
df_testcase
# Out:
#        Category                                               Text        ID  \
# 0   System Test                                   PreCondition TSR   9649554
# 7   System Test               Degradation Critical Reason Selftest   9651351
# 8   System Test                      Driving direction not forward  11444422
# 9   System Test                          Activation of Robust Mode  11444424
# 10  System Test                    Speed less than lower threshold  11444426
# 11  System Test                 Speed greater than upper threshold  11444428
# 12  System Test   Degradation Critical Reason Selftest_No_Priority  12208730
# 13  System Test  Degradation Critical Reason Selftest_Priority_...  12208733
# 15  System Test          Degradation Critical Reason Sensorblocked   9651355
# 16  System Test  Degradation Critical Reason Sensorblocked_No_P...  12208741
# 17  System Test  Degradation Critical Reason Sensorblocked_Prio...  12208743
# 18  System Test       Degradation Critical Reason SensorMisaligned   9651357
# 19  System Test  Degradation Critical Reason SensorMisaligned_N...  12208749
# 20  System Test  Degradation Critical Reason SensorMisaligned_P...  12208765
# 21  System Test    Degradation Critical Reason Input_Not_Available   9651359
# 22  System Test  Degradation Critical Reason Input_Not_Availabl...  12208791
# 23  System Test  Degradation Critical Reason Input_Not_Availabl...  12208793
# 24  System Test  Degradation Critical Reason Sensor_Misaligned_...  11444430
# 25  System Test  Degradation Critical Reason Sensor_Misaligned_...  12208795
# 26  System Test  Degradation Critical Reason Sensor_Misaligned_...  12208797
# 27  System Test         Degradation Critical Reason External_Fault  11444432
# 28  System Test  Degradation Critical Reason External_Fault_No_...  12208799
# 29  System Test  Degradation Critical Reason External_Fault_Pri...  12208801
# 30  System Test          Degradation Low Reason ReducedFieldofView   9651361
# 31  System Test  Degradation Low Reason ReducedFieldofView_No_P...  12208803
# 32  System Test  Degradation Low Reason ReducedFieldofView_Prio...  12208807
# 33  System Test  Degradation Low Reason SensorBadEnvironmentCon...   9651363
# 34  System Test  Degradation Low Reason SensorBadEnvironmentCon...  12208809
# 35  System Test  Degradation Low Reason SensorBadEnvironmentCon...  12208812
# 36  System Test         Degradation Low Reason SensorNotCalibrated   9651365
# 37  System Test                      Driving direction not forward   9651367
# 38  System Test                          Activation of Robust Mode   9651369
# 39  System Test                    Speed less than lower threshold   9651371
# 40  System Test                 Speed greater than upper threshold  10727778
# 41  System Test  Degradation Low Reason SensorNotCalibrated_No_...  12208817
# 42  System Test  Degradation Low Reason SensorNotCalibrated_Pri...  12208819
# 43  System Test                                  PostCondition TSR  10726201
# 44  System Test  Degradation Critical Reason  Internal_Error_No...  11922652
# 45  System Test  Degradation Critical Reason  Internal_Error_No...  12208821
# 46  System Test  Degradation Critical Reason  Internal_Error_No...  12208823
# 47  System Test  Degradation Critical Reason  Internal_Error_Re...  11922654
# 48  System Test  Degradation Critical Reason  Internal_Error_Re...  12208829
# 49  System Test  Degradation Critical Reason  Internal_Error_Re...  12208838
#
#                                             Validates  \
# 0                                                 NaN
# 7                                  11266802, 10036670
# 8                                            11266802
# 9                                            11266802
# 10                                           11266802
# 11                                           11266802
# 12                                 11266802, 10036670
# 13                                 11266802, 10036670
# 15            12154407, 11267000, 11267008?, 10036670
# 16             12154407, 11267000, 11267008, 10036670
# 17             12154407, 11267000, 11267008, 10036670
# 18                                 10036670, 11266802
# 19                                 10036670, 11266802
# 20                                 10036670, 11266802
# 21                       10036670, 11266806, 11267062
# 22                       10036670, 11266806, 11267062
# 23                       10036670, 11266806, 11267062
# 24                       10036670, 11267020, 11267022
# 25                       10036670, 11267020, 11267022
# 26                       10036670, 11267020, 11267022
# 27                                 10036670, 11266948
# 28                                 10036670, 11266948
# 29                                 10036670, 11266948
# 30             12154424, 11267012, 11267010, 10036670
# 31             12154424, 11267012, 11267010, 10036670
# 32             12154424, 11267012, 11267010, 10036670
# 33  10036670, 12154144, 11267002, 11267004, 121545...
# 34  12154144, 11267004, 11267002, 12154520, 112670...
# 35  12154144, 11267004, 11267002, 12154520, 112670...
# 36                                 11266802, 10036670
# 37                                           10036668
# 38                                           10036668
# 39                                           10036668
# 40                                           10036668
# 41                                 11266802, 10036670
# 42                                 11266802, 10036670
# 43                                                NaN
# 44             11266930, 11266928, 11266798, 10036670
# 45             11266930, 11266928, 11266798, 10036670
# 46             11266930, 11266928, 11266798, 10036670
# 47  11266810, 11266812, 11266814, 11266816, 112668...
# 48  10036670, 11266810, 11266812, 11266814, 112668...
# 49  10036670, 11266810, 11266812, 11266814, 112668...
#
#                               External ID  Priority  \
# 0       TestEnvMonHil_Mite_FullyAutomated       Low
# 7        TestEnvMonHil_Mite_SemiAutomated  Critical
# 8        TestEnvMonHil_Mite_SemiAutomated  Critical
# 9        TestEnvMonHil_Mite_SemiAutomated  Critical
# 10       TestEnvMonHil_Mite_SemiAutomated  Critical
# 11       TestEnvMonHil_Mite_SemiAutomated  Critical
# 12       TestEnvMonHil_Mite_SemiAutomated  Critical
# 13       TestEnvMonHil_Mite_SemiAutomated  Critical
# 15       TestEnvMonHil_Mite_SemiAutomated  Critical
# 16       TestEnvMonHil_Mite_SemiAutomated  Critical
# 17       TestEnvMonHil_Mite_SemiAutomated  Critical
# 18       TestEnvMonHil_Mite_SemiAutomated  Critical
# 19       TestEnvMonHil_Mite_SemiAutomated  Critical
# 20       TestEnvMonHil_Mite_SemiAutomated  Critical
# 21       TestEnvMonHil_Mite_SemiAutomated  Critical
# 22       TestEnvMonHil_Mite_SemiAutomated  Critical
# 23       TestEnvMonHil_Mite_SemiAutomated  Critical
# 24       TestEnvMonHil_Mite_SemiAutomated  Critical
# 25       TestEnvMonHil_Mite_SemiAutomated  Critical
# 26       TestEnvMonHil_Mite_SemiAutomated  Critical
# 27       TestEnvMonHil_Mite_SemiAutomated  Critical
# 28       TestEnvMonHil_Mite_SemiAutomated  Critical
# 29       TestEnvMonHil_Mite_SemiAutomated  Critical
# 30       TestEnvMonHil_Mite_SemiAutomated       Low
# 31       TestEnvMonHil_Mite_SemiAutomated       Low
# 32       TestEnvMonHil_Mite_SemiAutomated       Low
# 33       TestEnvMonHil_Mite_SemiAutomated       Low
# 34       TestEnvMonHil_Mite_SemiAutomated       Low
# 35       TestEnvMonHil_Mite_SemiAutomated       Low
# 36       TestEnvMonHil_Mite_SemiAutomated       Low
# 37       TestEnvMonHil_Mite_SemiAutomated       Low
# 38       TestEnvMonHil_Mite_SemiAutomated       Low
# 39       TestEnvMonHil_Mite_SemiAutomated       Low
# 40       TestEnvMonHil_Mite_SemiAutomated       Low
# 41       TestEnvMonHil_Mite_SemiAutomated       Low
# 42       TestEnvMonHil_Mite_SemiAutomated       Low
# 43  TestEnvMonitor_Mite_Dlt_SemiAutomated       Low
# 44       TestEnvMonHil_Mite_SemiAutomated  Critical
# 45       TestEnvMonHil_Mite_SemiAutomated  Critical
# 46       TestEnvMonHil_Mite_SemiAutomated  Critical
# 47       TestEnvMonHil_Mite_SemiAutomated  Critical
# 48       TestEnvMonHil_Mite_SemiAutomated  Critical
# 49       TestEnvMonHil_Mite_SemiAutomated  Critical
#
#                                          Precondition  \
# 0                                                 NaN
# 7   Step 1 : Run Test Case 9649554 TestSequence\nS...
# 8   Step 1 : Run Test Case 9649554 TestSequence\nS...
# 9   Step 1 : Run Test Case 9649554 TestSequence\nS...
# 10  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 11  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 12  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 13  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 15  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 16  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 17  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 18  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 19  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 20  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 21  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 22  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 23  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 24  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 25  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 26  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 27  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 28  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 29  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 30  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 31  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 32  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 33  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 34  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 35  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 36  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 37  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 38  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 39  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 40  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 41  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 42  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 43                                                NaN
# 44  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 45  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 46  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 47  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 48  Step 1 : Run Test Case 9649554 TestSequence\nS...
# 49  Step 1 : Run Test Case 9649554 TestSequence\nS...
#
#                                   Magna-Test Sequence  \
# 0   Step 1 : Set ECU Input PowerSupplyOff to 0\nSt...
# 7   Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 8   Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 9   Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 10  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 11  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 12  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 13  Step 1 : Set ECU Calibration TSR_VS_Low_Functi...
# 15  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 16  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 17  Step 1 : Set ECU Calibration TSR_VS_Low_Functi...
# 18  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 19  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 20  Step 1 : Set ECU Calibration TSR_VS_Low_Functi...
# 21  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 22  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 23  Step 1 : Set ECU Calibration TSR_VS_Low_Functi...
# 24  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 25  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 26  Step 1 : Set ECU Calibration TSR_VS_Low_Functi...
# 27  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 28  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 29  Step 1 : Set ECU Calibration TSR_VS_Low_Functi...
# 30  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 31  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 32  Step 1 : Set ECU Calibration TSR_VS_Low_Functi...
# 33  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 34  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 35  Step 1 : Set ECU Calibration TSR_VS_Low_Functi...
# 36  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 37  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 38  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 39  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 40  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 41  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 42  Step 1 : Set ECU Calibration TSR_VS_Low_Functi...
# 43  Step 1 : Wait Time 1 for 1secs\nStep 2 : Send ...
# 44  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 45  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 46  Step 1 : Set ECU Calibration TSR_VS_Low_Functi...
# 47  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 48  Step 1 : Set ECU Calibration TSR_VS_Critical_F...
# 49  Step 1 : Set ECU Calibration TSR_VS_Low_Functi...
#
#                                    Postcondition
# 0                                            NaN
# 7   Step 1 : Run Test Case 10726201 TestSequence
# 8   Step 1 : Run Test Case 10726201 TestSequence
# 9   Step 1 : Run Test Case 10726201 TestSequence
# 10  Step 1 : Run Test Case 10726201 TestSequence
# 11  Step 1 : Run Test Case 10726201 TestSequence
# 12  Step 1 : Run Test Case 10726201 TestSequence
# 13  Step 1 : Run Test Case 10726201 TestSequence
# 15  Step 1 : Run Test Case 10726201 TestSequence
# 16  Step 1 : Run Test Case 10726201 TestSequence
# 17  Step 1 : Run Test Case 10726201 TestSequence
# 18  Step 1 : Run Test Case 10726201 TestSequence
# 19  Step 1 : Run Test Case 10726201 TestSequence
# 20  Step 1 : Run Test Case 10726201 TestSequence
# 21  Step 1 : Run Test Case 10726201 TestSequence
# 22  Step 1 : Run Test Case 10726201 TestSequence
# 23  Step 1 : Run Test Case 10726201 TestSequence
# 24  Step 1 : Run Test Case 10726201 TestSequence
# 25  Step 1 : Run Test Case 10726201 TestSequence
# 26  Step 1 : Run Test Case 10726201 TestSequence
# 27  Step 1 : Run Test Case 10726201 TestSequence
# 28  Step 1 : Run Test Case 10726201 TestSequence
# 29  Step 1 : Run Test Case 10726201 TestSequence
# 30  Step 1 : Run Test Case 10726201 TestSequence
# 31  Step 1 : Run Test Case 10726201 TestSequence
# 32  Step 1 : Run Test Case 10726201 TestSequence
# 33  Step 1 : Run Test Case 10726201 TestSequence
# 34  Step 1 : Run Test Case 10726201 TestSequence
# 35  Step 1 : Run Test Case 10726201 TestSequence
# 36  Step 1 : Run Test Case 10726201 TestSequence
# 37  Step 1 : Run Test Case 10726201 TestSequence
# 38  Step 1 : Run Test Case 10726201 TestSequence
# 39  Step 1 : Run Test Case 10726201 TestSequence
# 40  Step 1 : Run Test Case 10726201 TestSequence
# 41  Step 1 : Run Test Case 10726201 TestSequence
# 42  Step 1 : Run Test Case 10726201 TestSequence
# 43                                           NaN
# 44  Step 1 : Run Test Case 10726201 TestSequence
# 45  Step 1 : Run Test Case 10726201 TestSequence
# 46  Step 1 : Run Test Case 10726201 TestSequence
# 47  Step 1 : Run Test Case 10726201 TestSequence
# 48  Step 1 : Run Test Case 10726201 TestSequence
# 49  Step 1 : Run Test Case 10726201 TestSequence

# %%
df.drop(['fileversion','ShortName','process','testCaseShoortName','State','RequirementID','testcaseId','refId','refMode','modifiedBy','createdBy','modifiedBy','priority','externalId',
         'externalScriptName','createdDate','modifiedDate','automatedBehavioronError','tocomment','fromcomment','displayOnTree','displayOnTable','path','documentId','status','version',
         'updateversion','createdate','modifiedate','parentId','testcasePTCModifiedDate','summaryCategoriesModifyflag','descriptionModifyflag','testStepsModifyflag','preconditionModifyflag',
         'postconditionModifyflag','expectedResultsModifyflag','parameterPtclistModifyflag','StateModifyflag','priorityModifyflag','tocommentModifyflag','statusflag','traceabiltyMofifyflag',
         'mitescriptflag','checkBoxflag','testcaseenable','testScriptEditFlag','testScriptName','miteXmlData','deleterelations','insertLocation','testSteps'],axis=1,inplace=True)

# %%
df=pd.read_csv('C://Users//koushik//Desktop//project//data//flat_dataset//intermediate_dataset.csv')
df
# Out:
#                           Description  \
# 0                          3_Wake_RTC
# 1             SensePackVoltErr_Faults
# 2             SenseLoadVoltErr_Faults
# 3              SenseAuxVoltErr_Faults
# 4           Sensor Load Voltage Error
# ..                                ...
# 429            Communication SPI CVTN
# 430  Horse-shoe ISO-SPI Communication
# 431                   Wakeup Ignition
# 432   Battery SOP Discharge Algorithm
# 433                        SOP_charge
#
#                                           precondition postcondition  \
# 0            Step 1 : Run Test Case 1_InitializationNF           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4            Step 1 : Run Test Case 1_InitializationNF           NaN
# ..                                                 ...           ...
# 429  Step 1 : Run Test Case 1_InitializationNF Test...           NaN
# 430  Step 1 : Run Test Case 1_InitializationNF Test...           NaN
# 431                                                NaN           NaN
# 432  Step 1 : Run Test Case 1_InitializationNF Test...           NaN
# 433  Step 1 : Run Test Case 1_InitializationNF Test...           NaN
#
#            file_name                              CleanedParametersList  \
# 0    TestCase-105571  [{'no': '1', 'name': 'APP_Command.APP_State_Re...
# 1    TestCase-106122  [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...
# 2    TestCase-106124  [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...
# 3    TestCase-106126  [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...
# 4    TestCase-106128  [{'no': '1', 'name': 'HV_RELAY2.PACK_HV_POS', ...
# ..               ...                                                ...
# 429   TestCase-95292  [{'no': '1', 'name': 'HVESP01_modTemperature.H...
# 430   TestCase-95294  [{'no': '1', 'name': 'HVESP01_modTemperature.H...
# 431   TestCase-95296  [{'no': '1', 'name': 'APP_Command.APP_State_Re...
# 432   TestCase-99878  [{'no': '1', 'name': 'BATT_Sys_SOC.BATT_Sys_SO...
# 433   TestCase-99880  [{'no': '1', 'name': 'HVESP01_Data01.HVESP01_c...
#
#                                       CleanedParameter  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    [{'sno': '1', 'parametername': 'Battery_Sensor...
# ..                                                 ...
# 429                                                NaN
# 430                                                NaN
# 431  [{'sno': '1', 'parametername': 'LV_Current_mea...
# 432                                                NaN
# 433                                                NaN
#
#                                  CleanedTestCaseFormid
# 0    [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 1    [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 2    [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 3    [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 4    [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# ..                                                 ...
# 429  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 430  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 431  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 432  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 433  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
#
# [434 rows x 7 columns]

# %%
string='CleanedTestCaseFormid'
valid_dataframe= parse_column(df,string )
normalized_df=normalize_column(valid_dataframe,string )
normalized_df.head(3)
# Out:
# [NORMALIZED] 8 unique `file_name` values (from 434 in input)
#              type id idHead          action serviceType  \
# 0  Pre Conditions  0      #  Pre Conditions        None
# 1  Pre Conditions  1      1             Run   Test Case
# 2   Test Sequence  2      #   Test Sequence        None
#
#                           description  desiredValue extensions  \
# 0                                None          None       None
# 1  1_InitializationNF->TestCase-65019  TestSequence       None
# 2                                None          None       None
#
#                         comments               file_name
# 0                           None  TestCase-1711455611249
# 1        Set LabCar Defaults      TestCase-1711455611249
# 2                           None  TestCase-1711455611249

# %%
check_column = 'imageHideInformation'
print(normalized_df[check_column].isna().sum())
len(normalized_df[check_column].unique())
# Out:
# 22133
# 1

# %%
normalized_df[check_column].value_counts()
# Out:
# extnId
# $AND!       165
# EXTN$AND      9
# CLEAR         8
# Name: count, dtype: int64

# %%
normalized_df[normalized_df[check_column].notna()]
# Out:
#                 type  id idHead action stepData                 refId  \
# 4209   Test Sequence  12     10  Check     None  STEP_933927753396100
# 4213   Test Sequence  16     13  Check     None  STEP_933927753404700
# 4218   Test Sequence  21     18    Set     None  STEP_933927753409300
# 4219   Test Sequence  22   18.1  Check       SS  STEP_933927753410600
# 4222   Test Sequence  25     21  Check     None  STEP_935971219252700
# ...              ...  ..    ...    ...      ...                   ...
# 10335  Test Sequence  25     21  Check       53  STEP_936626693174100
# 10456  Test Sequence  25     21  Check     None  STEP_940711567733000
# 10626  Test Sequence   8      6  Check     None  STEP_937417652464500
# 10810  Test Sequence  16     14  Check        S    STEP_5132557647900
# 10822  Test Sequence  28     26  Check       25  STEP_117276984037700
#
#                     file_name serviceType  \
# 4209   TestCase-1711455610053  CAN Signal
# 4213   TestCase-1711455610053  CAN Signal
# 4218   TestCase-1711455610053  CAN Signal
# 4219   TestCase-1711455610053  CAN Signal
# 4222   TestCase-1711455610053  CAN Signal
# ...                       ...         ...
# 10335  TestCase-1745991142898  CAN Signal
# 10456  TestCase-1745991143751  CAN Signal
# 10626  TestCase-1745991207074  CAN Signal
# 10810  TestCase-1747384439128  CAN Signal
# 10822  TestCase-1747384439128  CAN Signal
#
#                                           description  desiredValue  \
# 4209        HVESP01_Data02.HVESP01_highestCellVoltage         >4.25
# 4213        HVESP01_Data02.HVESP01_highestCellVoltage           4.2
# 4218                                        Clear DTC             1
# 4219   BATT_Diagnostic_Pack_B.BATT_01_BrickOvercharge  0 - Inactive
# 4222       HVESP01_cellVoltage.HVESP01_cellVoltage_21         >4.25
# ...                                               ...           ...
# 10335      HVESP01_cellVoltage.HVESP01_cellVoltage_73         <4.13
# 10456      HVESP01_cellVoltage.HVESP01_cellVoltage_73          >2.8
# 10626   BATT_Sys_Temp_Module.BATT_Sys_Temp_Module_Max           >65
# 10810            BATT_Cnc_SOC.BATT_Cnc_SOC_String_Avg             5
# 10822   BATT_Sys_Temp_Module.BATT_Sys_Temp_Module_Max          50 C
#
#                                               extensions  \
# 4209                                                THEN
# 4213                     (with tolerance offset +/-0.01)
# 4218                                                THEN
# 4219   From {{BatteryBrickOverchargedPermanent_Fault_...
# 4222                                 with in  1mins THEN
# ...                                                  ...
# 10335                                with in  1mins THEN
# 10456                                     with in  1mins
# 10626                                               THEN
# 10810       (with tolerance offset +/-3) with in  30mins
# 10822                       (with tolerance offset +/-1)
#
#                                                 comments  \
# 4209                                                None
# 4213                                                None
# 4218   <p style="margin-top: 0">      CAPL script to ...
# 4219                                                None
# 4222                                                None
# ...                                                  ...
# 10335                                               None
# 10456                                               None
# 10626                                               None
# 10810                                               None
# 10822                                               None
#
#                                 extensionsHideInfomation extnId  \
# 4209   <empty>#<empty>#<empty>#<empty>#<empty>#<empty...  $AND!
# 4213   <empty>#<empty>#<empty>#<empty>#<empty># (with...  $AND!
# 4218   <empty>#<empty>#<empty>#<empty>#<empty>#<empty...  CLEAR
# 4219   <empty>#<empty>#<empty>#<empty>#<empty>#<empty...  CLEAR
# 4222   <empty>#<empty>#<empty>#<empty>#<empty>#<empty...  $AND!
# ...                                                  ...    ...
# 10335  <empty>#<empty>#<empty>#<empty>#<empty>#<empty...  $AND!
# 10456  <empty>#<empty>#<empty>#<empty>#<empty>#<empty...  $AND!
# 10626  <empty>#<empty>#<empty>#<empty>#<empty>#<empty...  $AND!
# 10810  <empty>#<empty>#<empty>#<empty>#<empty># (with...  $AND!
# 10822  <empty>#<empty>#<empty>#<empty>#<empty># (with...  $AND!
#
#        imageHideInformation
# 4209                    NaN
# 4213                    NaN
# 4218                    NaN
# 4219                    NaN
# 4222                    NaN
# ...                     ...
# 10335                   NaN
# 10456                   NaN
# 10626                   NaN
# 10810                   NaN
# 10822                   NaN
#
# [182 rows x 15 columns]

# %%
cols_to_drop = ['stepData','refId','extensionsHideInfomation','extnId','imageHideInformation']

# %%
grouped_df = clean_column(normalized_df, string, cols_to_drop)
# Out:
# nested_utils.ipynb:13: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ]

# %%
df.head(1)
# Out:
#   Description SummaryCategories  \
# 0  3_Wake_RTC        Test - HIL
#
#                                      expectedResults  \
# 0  Test Sequence :<br>At Step 3 : ECU Variable Sl...
#
#                                         precondition postcondition  \
# 0  Step 1 : Run Test Case <a href="mks:///item?it...           NaN
#
#                                       TestCaseFormid        file_name  \
# 0  [{'type': 'Pre Conditions', 'id': '0', 'idHead...  TestCase-105571
#
#   CleanedRelationShips                              CleanedParametersList  \
# 0                  NaN  [{'no': '1', 'name': 'APP_Command.APP_State_Re...
#
#   CleanedParameterValues CleanedParameter
# 0                    NaN              NaN

# %%
df = merge_df(df, grouped_df,string)

# %%
df
# Out:
#                           Description SummaryCategories  \
# 0                          3_Wake_RTC        Test - HIL
# 1             SensePackVoltErr_Faults        Test - HIL
# 2             SenseLoadVoltErr_Faults        Test - HIL
# 3              SenseAuxVoltErr_Faults        Test - HIL
# 4           Sensor Load Voltage Error        Test - HIL
# ..                                ...               ...
# 429            Communication SPI CVTN        Test - HIL
# 430  Horse-shoe ISO-SPI Communication        Test - HIL
# 431                   Wakeup Ignition        Test - HIL
# 432   Battery SOP Discharge Algorithm        Test - HIL
# 433                        SOP_charge        Test - HIL
#
#                                        expectedResults  \
# 0    Test Sequence :<br>At Step 3 : ECU Variable Sl...
# 1    Test Sequence :<br>At Step 1 : CAN Signal BATT...
# 2    Test Sequence :<br>At Step 1 : CAN Signal BATT...
# 3    Test Sequence :<br>At Step 1 : CAN Signal BATT...
# 4    Test Sequence :<br>At Step 2 : CAN Signal BATT...
# ..                                                 ...
# 429  Test Sequence :<br>At Step 4 : CAN Signal HVES...
# 430  Test Sequence :<br>At Step 4 : CAN Signal HVES...
# 431                                                NaN
# 432  Test Sequence :<br>At Step 2 : CAN Signal HVES...
# 433  Test Sequence :<br>At Step 2 : CAN Signal HVES...
#
#                                           precondition postcondition  \
# 0    Step 1 : Run Test Case <a href="mks:///item?it...           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4    Step 1 : Run Test Case <a href="mks:///item?it...           NaN
# ..                                                 ...           ...
# 429  Step 1 : Run Test Case <a href="mks:///item?it...           NaN
# 430  Step 1 : Run Test Case <a href="mks:///item?it...           NaN
# 431                                                NaN           NaN
# 432  Step 1 : Run Test Case <a href="mks:///item?it...           NaN
# 433  Step 1 : Run Test Case <a href="mks:///item?it...           NaN
#
#            file_name                               CleanedRelationShips  \
# 0    TestCase-105571                                                NaN
# 1    TestCase-106122                                                NaN
# 2    TestCase-106124                                                NaN
# 3    TestCase-106126                                                NaN
# 4    TestCase-106128  [{'relationshipType': 'Requirement', 'relation...
# ..               ...                                                ...
# 429   TestCase-95292  [{'relationshipType': 'Requirement', 'relation...
# 430   TestCase-95294  [{'relationshipType': 'Requirement', 'relation...
# 431   TestCase-95296  [{'relationshipType': 'Requirement', 'relation...
# 432   TestCase-99878  [{'relationshipType': 'Requirement', 'relation...
# 433   TestCase-99880                                                NaN
#
#                                  CleanedParametersList CleanedParameterValues  \
# 0    [{'no': '1', 'name': 'APP_Command.APP_State_Re...                    NaN
# 1    [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...                    NaN
# 2    [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...                    NaN
# 3    [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...                    NaN
# 4    [{'no': '1', 'name': 'HV_RELAY2.PACK_HV_POS', ...                    NaN
# ..                                                 ...                    ...
# 429  [{'no': '1', 'name': 'HVESP01_modTemperature.H...                    NaN
# 430  [{'no': '1', 'name': 'HVESP01_modTemperature.H...                    NaN
# 431  [{'no': '1', 'name': 'APP_Command.APP_State_Re...                    NaN
# 432  [{'no': '1', 'name': 'BATT_Sys_SOC.BATT_Sys_SO...                    NaN
# 433  [{'no': '1', 'name': 'HVESP01_Data01.HVESP01_c...                    NaN
#
#                                       CleanedParameter  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    [{'sno': '1', 'parametername': 'Battery_Sensor...
# ..                                                 ...
# 429                                                NaN
# 430                                                NaN
# 431  [{'sno': '1', 'parametername': 'LV_Current_mea...
# 432                                                NaN
# 433                                                NaN
#
#                                  CleanedTestCaseFormid
# 0    [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 1    [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 2    [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 3    [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 4    [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# ..                                                 ...
# 429  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 430  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 431  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 432  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 433  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
#
# [434 rows x 11 columns]

# %%
df.to_csv("C://Users//koushik//Desktop//project//data//flat_dataset//intermediate_dataset.csv", index=False, encoding='utf-8')
