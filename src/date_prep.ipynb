# %%
import json
import numpy as np
import pandas as pd
import nbimporter
from nested_utils import (
    parse_column,
    normalize_column,
    clean_column,
    merge_df
)

# %%
df=pd.read_csv('C://Users//koushik//Desktop//project//data//flat_dataset//merged_output.csv')
df.columns = [col.split('.')[-1] for col in df.columns]
df = df[df['SummaryCategories'] != 'Folder']

# %%
'''

['fileversion','ShortName','Description','SummaryCategories','testCaseShoortName','process','State',
'RequirementID','expectedResults','testcaseId','refId','refMode','createdBy','modifiedBy','priority',
'externalId','externalScriptName','createdDate','modifiedDate','automatedBehavioronError','tocomment',
'fromcomment','displayOnTree','displayOnTable','precondition','postcondition','testSteps','path',
'documentId','status','version','updateversion','createdate','modifiedate','parentId','insertLocation',
'testcasePTCModifiedDate','summaryCategoriesModifyflag','descriptionModifyflag','testStepsModifyflag',
'preconditionModifyflag','postconditionModifyflag','expectedResultsModifyflag','parameterPtclistModifyflag',
'StateModifyflag','priorityModifyflag','tocommentModifyflag','statusflag','traceabiltyMofifyflag',
'mitescriptflag','checkBoxflag','testcaseenable','testScriptEditFlag','TestCaseFormid','ParametersList',
'deleterelations','file_name','Parameter','RelationShips','miteXmlData','testScriptName','ParameterValues']

'''
#  434 rows × 62 testScriptNamecolumns
# Out:
# "\n\n['fileversion','ShortName','Description','SummaryCategories','testCaseShoortName','process','State',\n'RequirementID','expectedResults','testcaseId','refId','refMode','createdBy','modifiedBy','priority',\n'externalId','externalScriptName','createdDate','modifiedDate','automatedBehavioronError','tocomment',\n'fromcomment','displayOnTree','displayOnTable','precondition','postcondition','testSteps','path',\n'documentId','status','version','updateversion','createdate','modifiedate','parentId','insertLocation',\n'testcasePTCModifiedDate','summaryCategoriesModifyflag','descriptionModifyflag','testStepsModifyflag',\n'preconditionModifyflag','postconditionModifyflag','expectedResultsModifyflag','parameterPtclistModifyflag',\n'StateModifyflag','priorityModifyflag','tocommentModifyflag','statusflag','traceabiltyMofifyflag',\n'mitescriptflag','checkBoxflag','testcaseenable','testScriptEditFlag','TestCaseFormid','ParametersList',\n'deleterelations','file_name','Parameter','RelationShips','miteXmlData','testScriptName','ParameterValues']\n\n"

# %%
string = 'deleterelations'
print(df[string].isna().sum())
len(df[string].unique())
# Out:
# 366
# 66

# %%
df[df[string].isna()]
# Out:
#      fileversion        ShortName                       Description  \
# 0            1.1  TestCase-105571                        3_Wake_RTC
# 2            1.1  TestCase-106122           SensePackVoltErr_Faults
# 3            1.1  TestCase-106124           SenseLoadVoltErr_Faults
# 4            1.1  TestCase-106126            SenseAuxVoltErr_Faults
# 5            1.1  TestCase-106128         Sensor Load Voltage Error
# ..           ...              ...                               ...
# 573          1.1   TestCase-95292            Communication SPI CVTN
# 574          1.1   TestCase-95294  Horse-shoe ISO-SPI Communication
# 575          1.1   TestCase-95296                   Wakeup Ignition
# 576          1.1   TestCase-99878   Battery SOP Discharge Algorithm
# 577          1.1   TestCase-99880                        SOP_charge
#
#     SummaryCategories testCaseShoortName  process   State  RequirementID  \
# 0          Test - HIL    TestCase-105571      NaN  Active            NaN
# 2          Test - HIL    TestCase-106122      NaN  Active            NaN
# 3          Test - HIL    TestCase-106124      NaN  Active            NaN
# 4          Test - HIL    TestCase-106126      NaN  Active            NaN
# 5          Test - HIL    TestCase-106128      NaN  Active            NaN
# ..                ...                ...      ...     ...            ...
# 573        Test - HIL     TestCase-95292      NaN  Active            NaN
# 574        Test - HIL     TestCase-95294      NaN  Active            NaN
# 575        Test - HIL     TestCase-95296      NaN  Active            NaN
# 576        Test - HIL     TestCase-99878      NaN  Active            NaN
# 577        Test - HIL     TestCase-99880      NaN  Active            NaN
#
#                                        expectedResults      testcaseId  ...  \
# 0    Test Sequence :<br>At Step 3 : ECU Variable Sl...  JB01_HILVR_203  ...
# 2    Test Sequence :<br>At Step 1 : CAN Signal BATT...  JB01_HILVR_220  ...
# 3    Test Sequence :<br>At Step 1 : CAN Signal BATT...  JB01_HILVR_221  ...
# 4    Test Sequence :<br>At Step 1 : CAN Signal BATT...  JB01_HILVR_222  ...
# 5    Test Sequence :<br>At Step 2 : CAN Signal BATT...  JB01_HILVR_223  ...
# ..                                                 ...             ...  ...
# 573  Test Sequence :<br>At Step 4 : CAN Signal HVES...  JB01_HILVR_186  ...
# 574  Test Sequence :<br>At Step 4 : CAN Signal HVES...  JB01_HILVR_187  ...
# 575                                                NaN  JB01_HILVR_188  ...
# 576  Test Sequence :<br>At Step 2 : CAN Signal HVES...  JB01_HILVR_199  ...
# 577  Test Sequence :<br>At Step 2 : CAN Signal HVES...  JB01_HILVR_200  ...
#
#      testScriptEditFlag                                     TestCaseFormid  \
# 0                  True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 2                  True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 3                  True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 4                  True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 5                  True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# ..                  ...                                                ...
# 573                True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 574                True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 575                True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 576                True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
# 577                True  [{'type': 'Pre Conditions', 'id': '0', 'idHead...
#
#                                         ParametersList deleterelations  \
# 0    [{'no': '1', 'name': 'APP_Command.APP_State_Re...             NaN
# 2    [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...             NaN
# 3    [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...             NaN
# 4    [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...             NaN
# 5    [{'no': '1', 'name': 'HV_RELAY2.PACK_HV_POS', ...             NaN
# ..                                                 ...             ...
# 573  [{'no': '1', 'name': 'HVESP01_modTemperature.H...             NaN
# 574  [{'no': '1', 'name': 'HVESP01_modTemperature.H...             NaN
# 575  {'no': '1', 'name': 'APP_Command.APP_State_Req...             NaN
# 576  [{'no': '1', 'name': 'BATT_Sys_SOC.BATT_Sys_SO...             NaN
# 577  [{'no': '1', 'name': 'HVESP01_Data01.HVESP01_c...             NaN
#
#            file_name                                          Parameter  \
# 0    TestCase-105571                                                NaN
# 2    TestCase-106122                                                NaN
# 3    TestCase-106124                                                NaN
# 4    TestCase-106126                                                NaN
# 5    TestCase-106128  [{'sno': '1', 'parametername': 'Battery_Sensor...
# ..               ...                                                ...
# 573   TestCase-95292                                                NaN
# 574   TestCase-95294                                                NaN
# 575   TestCase-95296  {'sno': '1', 'parametername': 'LV_Current_mean...
# 576   TestCase-99878                                                NaN
# 577   TestCase-99880                                                NaN
#
#                                          RelationShips miteXmlData  \
# 0                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
# 5    {'relationshipType': 'Requirement', 'relations...         NaN
# ..                                                 ...         ...
# 573  {'relationshipType': 'Requirement', 'relations...         NaN
# 574  {'relationshipType': 'Requirement', 'relations...         NaN
# 575  [{'relationshipType': 'Requirement', 'relation...         NaN
# 576  {'relationshipType': 'Requirement', 'relations...         NaN
# 577                                                NaN         NaN
#
#     testScriptName ParameterValues
# 0              NaN             NaN
# 2              NaN             NaN
# 3              NaN             NaN
# 4              NaN             NaN
# 5              NaN             NaN
# ..             ...             ...
# 573            NaN             NaN
# 574            NaN             NaN
# 575            NaN             NaN
# 576            NaN             NaN
# 577            NaN             NaN
#
# [366 rows x 62 columns]

# %%
df[string].value_counts()
# Out:
# deleterelations
# 124250,151156    2
# 50164            2
# 124301           2
# 149420           1
# 124256           1
#                 ..
# 124286           1
# 124524           1
# 124248           1
# 120468           1
# 50053            1
# Name: count, Length: 65, dtype: int64

# %%
df.drop(['fileversion','ShortName','process','testCaseShoortName','State','RequirementID','testcaseId','refId','refMode','modifiedBy','createdBy','modifiedBy','priority','externalId',
         'externalScriptName','createdDate','modifiedDate','automatedBehavioronError','tocomment','fromcomment','displayOnTree','displayOnTable','path','documentId','status','version',
         'updateversion','createdate','modifiedate','parentId','testcasePTCModifiedDate','summaryCategoriesModifyflag','descriptionModifyflag','testStepsModifyflag','preconditionModifyflag',
         'postconditionModifyflag','expectedResultsModifyflag','parameterPtclistModifyflag','StateModifyflag','priorityModifyflag','tocommentModifyflag','statusflag','traceabiltyMofifyflag',
         'mitescriptflag','checkBoxflag','testcaseenable','testScriptEditFlag','TestCaseFormid','testScriptName','miteXmlData','deleterelations','insertLocation'],axis=1,inplace=True)

# %%
string='Parameter'
valid_dataframe= parse_column(df,string )
normalized_df=normalize_column(valid_dataframe,string )
normalized_df.head(3)
# Out:
# [NORMALIZED] 268 unique `file_name` values (from 268 in input)
#   sno                               parametername description    type values  \
# 0   1       Battery_SensorPackVoltageError_Charge        None  String      1
# 1   2  Battery_SensorPackVoltageError_ChargeEntry        None  String      1
# 2   3        Battery_SensorPackVoltageError_Drive        None  String      0
#
#   currentvalue valuedescription units  \
# 0            1             None  None
# 1            1             None  None
# 2            0             None  None
#
#                                      referencenumber         parameterID  \
# 0  (TestCase-106128,STEP_1690691857277400,4)*(Tes...  P_1809276730766200
# 1  (TestCase-106128,STEP_1682187084898000,4)*(Tes...  P_1809276731826700
# 2  (TestCase-106128,STEP_1682187084899600,4)*(Tes...  P_1809276732890800
#
#   valuesetin        file_name
# 0       true  TestCase-106128
# 1       true  TestCase-106128
# 2       true  TestCase-106128

# %%
cols_to_drop = ['commonname','longshortname','labeltype','datatype','referencenumber','reloadflag','labelid']

# %%
grouped_df = clean_column(normalized_df, string, cols_to_drop)
grouped_df
# Out:
# nested_utils.ipynb:13: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   },
#            file_name                              CleanedParametersList
# 0    TestCase-105571  [{'no': '1', 'name': 'APP_Command.APP_State_Re...
# 1    TestCase-106122  [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...
# 2    TestCase-106124  [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...
# 3    TestCase-106126  [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...
# 4    TestCase-106128  [{'no': '1', 'name': 'HV_RELAY2.PACK_HV_POS', ...
# ..               ...                                                ...
# 385   TestCase-95292  [{'no': '1', 'name': 'HVESP01_modTemperature.H...
# 386   TestCase-95294  [{'no': '1', 'name': 'HVESP01_modTemperature.H...
# 387   TestCase-95296  [{'no': '1', 'name': 'APP_Command.APP_State_Re...
# 388   TestCase-99878  [{'no': '1', 'name': 'BATT_Sys_SOC.BATT_Sys_SO...
# 389   TestCase-99880  [{'no': '1', 'name': 'HVESP01_Data01.HVESP01_c...
#
# [390 rows x 2 columns]

# %%
df
# Out:
#                           Description SummaryCategories  \
# 0                          3_Wake_RTC        Test - HIL
# 2             SensePackVoltErr_Faults        Test - HIL
# 3             SenseLoadVoltErr_Faults        Test - HIL
# 4              SenseAuxVoltErr_Faults        Test - HIL
# 5           Sensor Load Voltage Error        Test - HIL
# ..                                ...               ...
# 573            Communication SPI CVTN        Test - HIL
# 574  Horse-shoe ISO-SPI Communication        Test - HIL
# 575                   Wakeup Ignition        Test - HIL
# 576   Battery SOP Discharge Algorithm        Test - HIL
# 577                        SOP_charge        Test - HIL
#
#                                        expectedResults  \
# 0    Test Sequence :<br>At Step 3 : ECU Variable Sl...
# 2    Test Sequence :<br>At Step 1 : CAN Signal BATT...
# 3    Test Sequence :<br>At Step 1 : CAN Signal BATT...
# 4    Test Sequence :<br>At Step 1 : CAN Signal BATT...
# 5    Test Sequence :<br>At Step 2 : CAN Signal BATT...
# ..                                                 ...
# 573  Test Sequence :<br>At Step 4 : CAN Signal HVES...
# 574  Test Sequence :<br>At Step 4 : CAN Signal HVES...
# 575                                                NaN
# 576  Test Sequence :<br>At Step 2 : CAN Signal HVES...
# 577  Test Sequence :<br>At Step 2 : CAN Signal HVES...
#
#                                           precondition postcondition  \
# 0    Step 1 : Run Test Case <a href="mks:///item?it...           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4                                                  NaN           NaN
# 5    Step 1 : Run Test Case <a href="mks:///item?it...           NaN
# ..                                                 ...           ...
# 573  Step 1 : Run Test Case <a href="mks:///item?it...           NaN
# 574  Step 1 : Run Test Case <a href="mks:///item?it...           NaN
# 575                                                NaN           NaN
# 576  Step 1 : Run Test Case <a href="mks:///item?it...           NaN
# 577  Step 1 : Run Test Case <a href="mks:///item?it...           NaN
#
#                                              testSteps  \
# 0    Step 1 : Set CAN Signal APP_Command.APP_State_...
# 2    Step 1 : Check CAN Signal BATT_Diagnostic_Pack...
# 3    Step 1 : Check CAN Signal BATT_Diagnostic_Pack...
# 4    Step 1 : Check CAN Signal BATT_Diagnostic_Pack...
# 5    Step 1 : Set CAN Signal APP_Command.APP_State_...
# ..                                                 ...
# 573  Step 1 : Set CAN Signal NTC_Conversion/NTC_Tem...
# 574  Step 1 : Set CAN Signal NTC_Conversion/NTC_Tem...
# 575                                                NaN
# 576  Step 1 : Set CAN Signal Packmodel/Load_Current...
# 577  Step 1 : Set CAN Signal Packmodel/Load_Current...
#
#                                         ParametersList        file_name  \
# 0    [{'no': '1', 'name': 'APP_Command.APP_State_Re...  TestCase-105571
# 2    [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...  TestCase-106122
# 3    [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...  TestCase-106124
# 4    [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...  TestCase-106126
# 5    [{'no': '1', 'name': 'HV_RELAY2.PACK_HV_POS', ...  TestCase-106128
# ..                                                 ...              ...
# 573  [{'no': '1', 'name': 'HVESP01_modTemperature.H...   TestCase-95292
# 574  [{'no': '1', 'name': 'HVESP01_modTemperature.H...   TestCase-95294
# 575  {'no': '1', 'name': 'APP_Command.APP_State_Req...   TestCase-95296
# 576  [{'no': '1', 'name': 'BATT_Sys_SOC.BATT_Sys_SO...   TestCase-99878
# 577  [{'no': '1', 'name': 'HVESP01_Data01.HVESP01_c...   TestCase-99880
#
#                                              Parameter  \
# 0                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5    [{'sno': '1', 'parametername': 'Battery_Sensor...
# ..                                                 ...
# 573                                                NaN
# 574                                                NaN
# 575  {'sno': '1', 'parametername': 'LV_Current_mean...
# 576                                                NaN
# 577                                                NaN
#
#                                          RelationShips ParameterValues
# 0                                                  NaN             NaN
# 2                                                  NaN             NaN
# 3                                                  NaN             NaN
# 4                                                  NaN             NaN
# 5    {'relationshipType': 'Requirement', 'relations...             NaN
# ..                                                 ...             ...
# 573  {'relationshipType': 'Requirement', 'relations...             NaN
# 574  {'relationshipType': 'Requirement', 'relations...             NaN
# 575  [{'relationshipType': 'Requirement', 'relation...             NaN
# 576  {'relationshipType': 'Requirement', 'relations...             NaN
# 577                                                NaN             NaN
#
# [434 rows x 11 columns]

# %%
df = merge_df(df, grouped_df,string)

# %%
df
# Out:
#                           Description SummaryCategories  \
# 0                          3_Wake_RTC        Test - HIL
# 1             SensePackVoltErr_Faults        Test - HIL
# 2             SenseLoadVoltErr_Faults        Test - HIL
# 3              SenseAuxVoltErr_Faults        Test - HIL
# 4           Sensor Load Voltage Error        Test - HIL
# ..                                ...               ...
# 429            Communication SPI CVTN        Test - HIL
# 430  Horse-shoe ISO-SPI Communication        Test - HIL
# 431                   Wakeup Ignition        Test - HIL
# 432   Battery SOP Discharge Algorithm        Test - HIL
# 433                        SOP_charge        Test - HIL
#
#                                        expectedResults  \
# 0    Test Sequence :<br>At Step 3 : ECU Variable Sl...
# 1    Test Sequence :<br>At Step 1 : CAN Signal BATT...
# 2    Test Sequence :<br>At Step 1 : CAN Signal BATT...
# 3    Test Sequence :<br>At Step 1 : CAN Signal BATT...
# 4    Test Sequence :<br>At Step 2 : CAN Signal BATT...
# ..                                                 ...
# 429  Test Sequence :<br>At Step 4 : CAN Signal HVES...
# 430  Test Sequence :<br>At Step 4 : CAN Signal HVES...
# 431                                                NaN
# 432  Test Sequence :<br>At Step 2 : CAN Signal HVES...
# 433  Test Sequence :<br>At Step 2 : CAN Signal HVES...
#
#                                           precondition postcondition  \
# 0    Step 1 : Run Test Case <a href="mks:///item?it...           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4    Step 1 : Run Test Case <a href="mks:///item?it...           NaN
# ..                                                 ...           ...
# 429  Step 1 : Run Test Case <a href="mks:///item?it...           NaN
# 430  Step 1 : Run Test Case <a href="mks:///item?it...           NaN
# 431                                                NaN           NaN
# 432  Step 1 : Run Test Case <a href="mks:///item?it...           NaN
# 433  Step 1 : Run Test Case <a href="mks:///item?it...           NaN
#
#                                              testSteps        file_name  \
# 0    Step 1 : Set CAN Signal APP_Command.APP_State_...  TestCase-105571
# 1    Step 1 : Check CAN Signal BATT_Diagnostic_Pack...  TestCase-106122
# 2    Step 1 : Check CAN Signal BATT_Diagnostic_Pack...  TestCase-106124
# 3    Step 1 : Check CAN Signal BATT_Diagnostic_Pack...  TestCase-106126
# 4    Step 1 : Set CAN Signal APP_Command.APP_State_...  TestCase-106128
# ..                                                 ...              ...
# 429  Step 1 : Set CAN Signal NTC_Conversion/NTC_Tem...   TestCase-95292
# 430  Step 1 : Set CAN Signal NTC_Conversion/NTC_Tem...   TestCase-95294
# 431                                                NaN   TestCase-95296
# 432  Step 1 : Set CAN Signal Packmodel/Load_Current...   TestCase-99878
# 433  Step 1 : Set CAN Signal Packmodel/Load_Current...   TestCase-99880
#
#                                              Parameter  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    [{'sno': '1', 'parametername': 'Battery_Sensor...
# ..                                                 ...
# 429                                                NaN
# 430                                                NaN
# 431  {'sno': '1', 'parametername': 'LV_Current_mean...
# 432                                                NaN
# 433                                                NaN
#
#                                          RelationShips ParameterValues  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                                  NaN             NaN
# 3                                                  NaN             NaN
# 4    {'relationshipType': 'Requirement', 'relations...             NaN
# ..                                                 ...             ...
# 429  {'relationshipType': 'Requirement', 'relations...             NaN
# 430  {'relationshipType': 'Requirement', 'relations...             NaN
# 431  [{'relationshipType': 'Requirement', 'relation...             NaN
# 432  {'relationshipType': 'Requirement', 'relations...             NaN
# 433                                                NaN             NaN
#
#                                  CleanedParametersList
# 0    [{'no': '1', 'name': 'APP_Command.APP_State_Re...
# 1    [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...
# 2    [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...
# 3    [{'no': '1', 'name': 'BATT_Diagnostic_Pack_B.B...
# 4    [{'no': '1', 'name': 'HV_RELAY2.PACK_HV_POS', ...
# ..                                                 ...
# 429  [{'no': '1', 'name': 'HVESP01_modTemperature.H...
# 430  [{'no': '1', 'name': 'HVESP01_modTemperature.H...
# 431  [{'no': '1', 'name': 'APP_Command.APP_State_Re...
# 432  [{'no': '1', 'name': 'BATT_Sys_SOC.BATT_Sys_SO...
# 433  [{'no': '1', 'name': 'HVESP01_Data01.HVESP01_c...
#
# [434 rows x 11 columns]

# %%
##Parameter
